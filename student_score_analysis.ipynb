# 46       1047  Student_47   7.0      1.0     96.0     54.0     B
# 47       1048  Student_48   NaN     89.0     60.0     89.0     A
# 48       1049  Student_49  80.0     31.0      3.0     22.0     D
# 49       1050  Student_50  34.0     54.0      NaN     11.0     C
#
#     AttendancePercentage
# 0                     79
# 1                     83
# 2                     71
# 3                     94
# 4                     92
# 5                     92
# 6                     96
# 7                     71
# 8                     62
# 9                     60
# 10                    92
# 11                    99
# 12                    69
# 13                    88
# 14                    72
# 15                    71
# 16                    90
# 17                    61
# 18                    94
# 19                    82
# 20                    76
# 21                    85
# 22                    67
# 23                    88
# 24                    85
# 25                    69
# 26                    85
# 27                    93
# 28                    66
# 29                    63
# 30                    70
# 31                    88
# 32                    95
# 33                    84
# 34                    80
# 35                    95
# 36                    69
# 37                    96
# 38                    68
# 39                    83
# 40                    94
# 41                    94
# 42                    95
# 43                    77
# 44                    98
# 45                    91
# 46                    83
# 47                    82
# 48                    91
# 49                    96

# %%
shape=df.shape
print(f"Shape:{shape}")
# Out:
# Shape:(50, 8)

# %%
print("\n--- Dataset Info ---")
df.info()
# Out:
# --- Dataset Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   StudentID             50 non-null     int64
#  1   Name                  50 non-null     object
#  2   Math                  40 non-null     float64
#  3   Science               47 non-null     float64
#  4   English               47 non-null     float64
#  5   History               45 non-null     float64
#  6   Grade                 50 non-null     object
#  7   AttendancePercentage  50 non-null     int64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 3.3+ KB

# %%
print("\n--- Basic Statistics ---")
df.describe()
# Out:
# --- Basic Statistics ---
#         StudentID       Math    Science    English    History  \
# count    50.00000  40.000000  47.000000  47.000000  45.000000
# mean   1025.50000  45.750000  50.319149  41.170213  42.444444
# std      14.57738  31.264586  29.805242  29.300036  27.820492
# min    1001.00000   2.000000   0.000000   0.000000   4.000000
# 25%    1013.25000  13.750000  29.000000  18.000000  21.000000
# 50%    1025.50000  43.500000  54.000000  36.000000  41.000000
# 75%    1037.75000  71.000000  71.000000  59.500000  62.000000
# max    1050.00000  99.000000  98.000000  97.000000  98.000000
#
#        AttendancePercentage
# count             50.000000
# mean              82.480000
# std               11.556851
# min               60.000000
# 25%               71.000000
# 50%               84.500000
# 75%               92.750000
# max               99.000000

# %% [markdown]
# ## Q3.2: Average Score Calculation

# %% [markdown]
# #### Calculate the average score across all subjects (Math, Science, English, History) for each student

# %%
subjects=df[['Math','Science','English','History']]
df['Avg_score']=subjects.mean(axis=1)
print("\n---Average_score for each Student---")
df['Avg_score'].head(10)
# Out:
# ---Average_score for each Student---
# 0    32.000000
# 1    40.750000
# 2    64.000000
# 3    26.333333
# 4    53.000000
# 5    54.750000
# 6    84.000000
# 7    50.750000
# 8    70.500000
# 9    30.000000
# Name: Avg_score, dtype: float64

# %%
df
# Out:
#     StudentID        Name  Math  Science  English  History Grade  \
# 0        1001   Student_1  92.0      4.0     16.0     16.0     F
# 1        1002   Student_2  71.0     40.0     23.0     29.0     A
# 2        1003   Student_3  82.0     72.0     97.0      5.0     B
# 3        1004   Student_4   NaN     33.0     10.0     36.0     B
# 4        1005   Student_5  99.0      NaN     15.0     45.0     A
# 15                    71  46.750000
# 16                    90  42.500000
# 17                    61  29.750000
# 18                    94  31.000000
# 19                    82  29.500000
# 20                    76  32.000000
# 21                    85  37.333333
# 22                    67  37.500000
# 23                    88  18.500000
# 24                    85  24.333333
# 25                    69  57.000000
# 26                    85  37.500000
# 27                    93  51.000000
# 28                    66  78.666667
# 29                    63  61.333333
# 30                    70  45.750000
# 31                    88  45.750000
# 32                    95  47.750000
# 33                    84  37.750000
# 34                    80  64.750000
# 35                    95  55.000000
# 36                    69  54.500000
# 37                    96  46.500000
# 38                    68  41.000000
# 39                    83  68.000000
# 40                    94  39.250000
# 41                    94  54.750000
# 42                    95  34.000000
# 43                    77  25.000000
# 44                    98  53.000000
# 45                    91  57.000000
# 46                    83  39.500000
# 47                    82  79.333333
# 48                    91  34.000000
# 49                    96  33.000000

# %% [markdown]
# ## Q3.3: Missing Value Handling

# %% [markdown]
# #### Fill missing values in Math, Science, and English with their respective column means.

# %%
df.isnull().sum()
# Out:
# StudentID                0
# Name                     0
# Math                    10
# Science                  3
# English                  3
# History                  5
# Grade                    0
# AttendancePercentage     0
# Avg_score                0
# dtype: int64

# %%
df['Math'].fillna(df['Math'].mean(), inplace=True)
# Out:
# C:\Users\USER 10\AppData\Local\Temp\ipykernel_14988\3025746023.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Math'].fillna(df['Math'].mean(), inplace=True)

# %%
df['Science'].fillna(df['Science'].mean(), inplace=True)
# Out:
# C:\Users\USER 10\AppData\Local\Temp\ipykernel_14988\2374971838.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Science'].fillna(df['Science'].mean(), inplace=True)

# %%
df['English'].fillna(df['English'].mean(), inplace=True)
# Out:
# C:\Users\USER 10\AppData\Local\Temp\ipykernel_14988\259178685.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['English'].fillna(df['English'].mean(), inplace=True)

# %%
df['History'].fillna(df['History'].mean(), inplace=True)
# Out:
# C:\Users\USER 10\AppData\Local\Temp\ipykernel_14988\2668831522.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['History'].fillna(df['History'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# StudentID               0
# Name                    0
# Math                    0
# Science                 0
# English                 0
# History                 0
# Grade                   0
# AttendancePercentage    0
# Avg_score               0
# dtype: int64

# %%
df
# Out:
#     StudentID        Name   Math    Science    English    History Grade  \
# 0        1001   Student_1  92.00   4.000000  16.000000  16.000000     F
# 1        1002   Student_2  71.00  40.000000  23.000000  29.000000     A
# 2        1003   Student_3  82.00  72.000000  97.000000   5.000000     B
# 3        1004   Student_4  45.75  33.000000  10.000000  36.000000     B
# 4        1005   Student_5  99.00  50.319149  15.000000  45.000000     A
# 5        1006   Student_6   2.00  61.000000  58.000000  98.000000     B
# 6        1007   Student_7  45.75  98.000000  92.000000  62.000000     A
# 7        1008   Student_8  29.00  85.000000  58.000000  31.000000     F
# 8        1009   Student_9  63.00  64.000000  89.000000  66.000000     F
# 9        1010  Student_10  32.00  46.000000  18.000000  24.000000     A
# 10       1011  Student_11  21.00   0.000000  70.000000  53.000000     F
# 11       1012  Student_12  45.75  13.000000  32.000000  45.000000     F
# 12       1013  Student_13  45.75   8.000000  38.000000  42.444444     F
# 13       1014  Student_14  41.00  89.000000   0.000000  85.000000     C
# 14       1015  Student_15  45.75  50.319149  56.000000  26.000000     D
# 15       1016  Student_16  14.00  62.000000  22.000000  89.000000     B
# 16       1017  Student_17  46.00  51.000000  41.000000  32.000000     C
# 17       1018  Student_18  54.00   3.000000  15.000000  47.000000     F
# 40                    94  39.250000
# 41                    94  54.750000
# 42                    95  34.000000
# 43                    77  25.000000
# 44                    98  53.000000
# 45                    91  57.000000
# 46                    83  39.500000
# 47                    82  79.333333
# 48                    91  34.000000
# 49                    96  33.000000

# %% [markdown]
# ## Q3.4: Filtering by Performance

# %% [markdown]
# #### Filter students with an average score above the overall mean and display their names and average scores.

# %%
overall_mean=df['Avg_score'].mean()
overall_mean
# Out:
# np.float64(45.20166666666666)

# %%
above_mean=df[df['Avg_score']>overall_mean]
above_mean
# Out:
#     StudentID        Name   Math    Science    English    History Grade  \
# 2        1003   Student_3  82.00  72.000000  97.000000   5.000000     B
# 4        1005   Student_5  99.00  50.319149  15.000000  45.000000     A
# 5        1006   Student_6   2.00  61.000000  58.000000  98.000000     B
# 6        1007   Student_7  45.75  98.000000  92.000000  62.000000     A
# 7        1008   Student_8  29.00  85.000000  58.000000  31.000000     F
# 8        1009   Student_9  63.00  64.000000  89.000000  66.000000     F
# 13       1014  Student_14  41.00  89.000000   0.000000  85.000000     C
# 15       1016  Student_16  14.00  62.000000  22.000000  89.000000     B
# 25       1026  Student_26  91.00  27.000000  53.000000  42.444444     D
# 27       1028  Student_28   7.00  61.000000  71.000000  65.000000     B
# 28       1029  Student_29  45.75  91.000000  83.000000  62.000000     F
# 29       1030  Student_30  35.00  61.000000  88.000000  42.444444     D
# 30       1031  Student_31   3.00  26.000000  92.000000  62.000000     A
# 31       1032  Student_32   5.00  76.000000  81.000000  21.000000     F
# 32       1033  Student_33   3.00  69.000000  34.000000  85.000000     B
# 34       1035  Student_35  43.00  96.000000  67.000000  53.000000     F
# 35       1036  Student_36  61.00  43.000000  20.000000  96.000000     D
# 36       1037  Student_37  94.00  58.000000   7.000000  59.000000     B
# 37       1038  Student_38  71.00  95.000000  16.000000   4.000000     D
# 39       1040  Student_40  79.00  57.000000  41.170213  42.444444     B
# 41       1042  Student_42  88.00  55.000000  37.000000  39.000000     B
# 44       1045  Student_45  45.75  86.000000  20.000000  42.444444     F
# 45       1046  Student_46  87.00  96.000000  27.000000  18.000000     D
# 47       1048  Student_48  45.75  89.000000  60.000000  89.000000     A
#
#     AttendancePercentage  Avg_score
# 2                     71  64.000000
# 4                     92  53.000000
# 5                     92  54.750000
# 6                     96  84.000000
# 7                     71  50.750000
# 8                     62  70.500000
# 13                    88  53.750000
# 15                    71  46.750000
# 25                    69  57.000000
# 27                    93  51.000000
# 28                    66  78.666667
# 29                    63  61.333333
# 30                    70  45.750000
# 31                    88  45.750000
# 32                    95  47.750000
# 34                    80  64.750000
# 35                    95  55.000000
# 36                    69  54.500000
# 37                    96  46.500000
# 39                    83  68.000000
# 41                    94  54.750000
# 44                    98  53.000000
# 45                    91  57.000000
# 47                    82  79.333333

# %%
print(f"Overall Average Score: {overall_mean:.2f}")
print(f"\nStudents Above Average ({len(above_mean)} students):")
print(above_mean[['Name', 'Avg_score']].sort_values('Avg_score', ascending=False))
# Out:
# Overall Average Score: 45.20
#
# Students Above Average (24 students):
#           Name  Avg_score
# 6    Student_7  84.000000
# 33       1034  Student_34  62.00   8.000000  40.000000  41.000000     B
# 34       1035  Student_35  43.00  96.000000  67.000000  53.000000     F
# 35       1036  Student_36  61.00  43.000000  20.000000  96.000000     D
# 36       1037  Student_37  94.00  58.000000   7.000000  59.000000     B
# 37       1038  Student_38  71.00  95.000000  16.000000   4.000000     D
# 38       1039  Student_39  61.00  51.000000  47.000000   5.000000     B
# 39       1040  Student_40  79.00  57.000000  41.170213  42.444444     B
# 40       1041  Student_41  52.00  38.000000  21.000000  46.000000     C
# 41       1042  Student_42  88.00  55.000000  37.000000  39.000000     B
# 42       1043  Student_43  40.00  50.319149  50.000000  12.000000     A
# 43       1044  Student_44  44.00   1.000000  26.000000  29.000000     F
# 44       1045  Student_45  45.75  86.000000  20.000000  42.444444     F
# 45       1046  Student_46  87.00  96.000000  27.000000  18.000000     D
# 46       1047  Student_47   7.00   1.000000  96.000000  54.000000     B
# 47       1048  Student_48  45.75  89.000000  60.000000  89.000000     A
# 48       1049  Student_49  80.00  31.000000   3.000000  22.000000     D
# 49       1050  Student_50  34.00  54.000000  41.170213  11.000000     C
#
#     AttendancePercentage  Avg_score
# 0                     79  32.000000
# 1                     83  40.750000
# 2                     71  64.000000
# 3                     94  26.333333
# 4                     92  53.000000
# 5                     92  54.750000
# 6                     96  84.000000
# 7                     71  50.750000
# 8                     62  70.500000
# 9                     60  30.000000
# 10                    92  36.000000
# 11                    99  30.000000
# 12                    69  23.000000
# 13                    88  53.750000
# 14                    72  41.000000
# 15                    71  46.750000
# 16                    90  42.500000
# 17                    61  29.750000
# 18                    94  31.000000
# 19                    82  29.500000
# 20                    76  32.000000
# 21                    85  37.333333
# 22                    67  37.500000
# 23                    88  18.500000
# 24                    85  24.333333
# 25                    69  57.000000
# 26                    85  37.500000
# 27                    93  51.000000
# 28                    66  78.666667
# 29                    63  61.333333
# 30                    70  45.750000
# 31                    88  45.750000
# 32                    95  47.750000
# 33                    84  37.750000
# 34                    80  64.750000
# 35                    95  55.000000
# 36                    69  54.500000
# 37                    96  46.500000
# 38                    68  41.000000
# 39                    83  68.000000
# 40                    94  39.250000
# 41                    94  54.750000
# 42                    95  34.000000
# 43                    77  25.000000
# 44                    98  53.000000
# 45                    91  57.000000
# 46                    83  39.500000
# 47                    82  79.333333
# 48                    91  34.000000
# 49                    96  33.000000

# %%
print(f"Updated Math score for StudentID {student_id}:")
print(df.loc[df['StudentID'] == student_id, ['Name', 'Math', 'Avg_score']])
# Out:
# Updated Math score for StudentID 1001:
#         Name  Math  Avg_score
# 0  Student_1  82.0       32.0

# %% [markdown]
# ## Q3.6: Integer-based Selection (iloc)

# %% [markdown]
# #### Use iloc[] to select the first 10 rows and the last 3 columns, display them

# %%
data=df.iloc[0:10, 3:] # It is used to select the rows from 0 to 9 and columns from 3 to last
data
# Out:
#      Science  English  History Grade  AttendancePercentage  Avg_score
# 0   4.000000     16.0     16.0     F                    79  32.000000
# 1  40.000000     23.0     29.0     A                    83  40.750000
# 2  72.000000     97.0      5.0     B                    71  64.000000
# 3  33.000000     10.0     36.0     B                    94  26.333333
# 4  50.319149     15.0     45.0     A                    92  53.000000
# 5  61.000000     58.0     98.0     B                    92  54.750000
# 6  98.000000     92.0     62.0     A                    96  84.000000
# 7  85.000000     58.0     31.0     F                    71  50.750000
# 8  64.000000     89.0     66.0     F                    62  70.500000
# 9  46.000000     18.0     24.0     A                    60  30.000000

# %%
subset= df.iloc[0:10, -3:] # It is used to select the rows from 0 to 9 and columns last 3 rows only

# %%
print("First 10 Rows,last 3 Columns")
print(subset)
# Out:
# First 10 Rows,last 3 Columns
#   Grade  AttendancePercentage  Avg_score
# 0     F                    79  32.000000
# 1     A                    83  40.750000
# 2     B                    71  64.000000
# 3     B                    94  26.333333
# 4     A                    92  53.000000
# 5     B                    92  54.750000
# 6     A                    96  84.000000
# 7     F                    71  50.750000
# 8     F                    62  70.500000
# 9     A                    60  30.000000

# %% [markdown]
# ## Q3.7: Sorting

# %% [markdown]
# #### Sort students by AttendancePercentage in descending order and display the top 5

# %%
sort=df.sort_values(by='AttendancePercentage',ascending=False)
sort.head()
# Out:
#     StudentID        Name   Math  Science    English    History Grade  \
# 11       1012  Student_12  45.75     13.0  32.000000  45.000000     F
# 44       1045  Student_45  45.75     86.0  20.000000  42.444444     F
# 37       1038  Student_38  71.00     95.0  16.000000   4.000000     D
# 49       1050  Student_50  34.00     54.0  41.170213  11.000000     C
# 6        1007   Student_7  45.75     98.0  92.000000  62.000000     A
#
#     AttendancePercentage  Avg_score
# 11                    99       30.0
# 44                    98       53.0
# 37                    96       46.5
# 49                    96       33.0
# 6                     96       84.0

# %%
top_attendance = df.nlargest(5, 'AttendancePercentage')
print("Top 5 Students by Attendance:")
print(top_attendance[['Name', 'AttendancePercentage', 'Grade']])
# Out:
# Top 5 Students by Attendance:
#           Name  AttendancePercentage Grade
# 11  Student_12                    99     F
# 44  Student_45                    98     F
# 6    Student_7                    96     A
# 37  Student_38                    96     D
# 49  Student_50                    96     C

# %% [markdown]
# ## Q3.8: Conditional Column Creation

# %% [markdown]
# #### Create a new column 'PassFail' where 'Pass' if average score > 50, else 'Fail'

# %%
# lambda- It is a nameless function to written in one line
# apply- to perform a custom operation on each value or rows or columns

# %%
df['PassFail'] = df['Avg_score'].apply(lambda x: 'Pass' if x > 50 else 'Fail')
print("Pass/Fail Distribution:")
print(df['PassFail'].value_counts())
print(df[['Name', 'Avg_score', 'PassFail']].head(10))
# Out:
# Pass/Fail Distribution:
# PassFail
# Fail    31
# Pass    19
# Name: count, dtype: int64
#          Name  Avg_score PassFail
# 0   Student_1  32.000000     Fail
# 1   Student_2  40.750000     Fail
# 2   Student_3  64.000000     Pass
# 3   Student_4  26.333333     Fail
# 4   Student_5  53.000000     Pass
# 5   Student_6  54.750000     Pass
# 6   Student_7  84.000000     Pass
# 7   Student_8  50.750000     Pass
# 8   Student_9  70.500000     Pass
# 9  Student_10  30.000000     Fail

# %% [markdown]
# ## Q3.9: Duplicate Removal

# %% [markdown]
# #### Identify and remove duplicate rows (if any) based on all columns.

# %%
duplicates=df.duplicated().sum()
duplicates
# Out:
# np.int64(0)

# %% [markdown]
# ## Q3.10: Data Export

# %% [markdown]
# #### Export the cleaned and processed data to student_scores_cleaned.csv.

# %%
cleaned=df.to_csv('student_scores_cleaned.csv',index=False)

# %% [markdown]
# ## Challenge Extension

# %% [markdown]
# ### Challenge 1
# #### Create a grade categorization (A, B, C, D, F) based on average scores

# %%
# lambda- It is a nameless function to written in one line
# apply- to perform a custom operation on each value or rows or columns
df['Grade_Name'] = df['Avg_score'].apply(
    lambda x: 'A' if x >= 90 else
              'B' if x >= 75 else
              'C' if x >= 60 else
              'D' if x >= 50 else 'F'
)
print(df[['Name', 'Avg_score', 'Grade']])
df
# Out:
#           Name  Avg_score Grade
# 0    Student_1  32.000000     F
# 1    Student_2  40.750000     F
# 2    Student_3  64.000000     C
# 3    Student_4  26.333333     F
# 4    Student_5  53.000000     D
# 5    Student_6  54.750000     D
# 6    Student_7  84.000000     B
# 7    Student_8  50.750000     D
# 8    Student_9  70.500000     C
# 9   Student_10  30.000000     F
# 10  Student_11  36.000000     F
# 11  Student_12  30.000000     F
# 12  Student_13  23.000000     F
# 13  Student_14  53.750000     D
# 14  Student_15  41.000000     F
# 15  Student_16  46.750000     F
# 16  Student_17  42.500000     F
# 17  Student_18  29.750000     F
# 18  Student_19  31.000000     F
# 19  Student_20  29.500000     F
# 20  Student_21  32.000000     F
# 21  Student_22  37.333333     F
# 22  Student_23  37.500000     F
# 23  Student_24  18.500000     F
# 24  Student_25  24.333333     F
# 25  Student_26  57.000000     D
# 26  Student_27  37.500000     F
# 27  Student_28  51.000000     D
# 28  Student_29  78.666667     B
# 29  Student_30  61.333333     C
# 30  Student_31  45.750000     F
# 31  Student_32  45.750000     F
# 32  Student_33  47.750000     F
# 33  Student_34  37.750000     F
# 34  Student_35  64.750000     C
# 35  Student_36  55.000000     D
# 36  Student_37  54.500000     D
# 37  Student_38  46.500000     F
# 38  Student_39  41.000000     F
# 39  Student_40  68.000000     C
# 40  Student_41  39.250000     F
# 41  Student_42  54.750000     D
# 42  Student_43  34.000000     F
# 43  Student_44  25.000000     F
# 44  Student_45  53.000000     D
# 45  Student_46  57.000000     D
# 46  Student_47  39.500000     F
# 47  Student_48  79.333333     B
# 48  Student_49  34.000000     F
# 49  Student_50  33.000000     F
#     StudentID        Name   Math    Science    English    History Grade  \
# 0        1001   Student_1  82.00   4.000000  16.000000  16.000000     F
# 1        1002   Student_2  71.00  40.000000  23.000000  29.000000     F
# 2        1003   Student_3  82.00  72.000000  97.000000   5.000000     C
# 3        1004   Student_4  45.75  33.000000  10.000000  36.000000     F
# 4        1005   Student_5  99.00  50.319149  15.000000  45.000000     D
# 5        1006   Student_6   2.00  61.000000  58.000000  98.000000     D
# 6        1007   Student_7  45.75  98.000000  92.000000  62.000000     B
# 7        1008   Student_8  29.00  85.000000  58.000000  31.000000     D
# 8        1009   Student_9  63.00  64.000000  89.000000  66.000000     C
# 9        1010  Student_10  32.00  46.000000  18.000000  24.000000     F
# 10       1011  Student_11  21.00   0.000000  70.000000  53.000000     F
# 11                    99  30.000000     Fail              F          F
# 12                    69  23.000000     Fail              F          F
# 13                    88  53.750000     Pass              D          D
# 14                    72  41.000000     Fail              F          F
# 15                    71  46.750000     Fail              F          F
# 16                    90  42.500000     Fail              F          F
# 17                    61  29.750000     Fail              F          F
# 18                    94  31.000000     Fail              F          F
# 19                    82  29.500000     Fail              F          F
# 20                    76  32.000000     Fail              F          F
# 21                    85  37.333333     Fail              F          F
# 22                    67  37.500000     Fail              F          F
# 23                    88  18.500000     Fail              F          F
# 24                    85  24.333333     Fail              F          F
# 25                    69  57.000000     Pass              D          D
# 26                    85  37.500000     Fail              F          F
# 27                    93  51.000000     Pass              D          D
# 28                    66  78.666667     Pass              B          B
# 29                    63  61.333333     Pass              C          C
# 30                    70  45.750000     Fail              F          F
# 31                    88  45.750000     Fail              F          F
# 32                    95  47.750000     Fail              F          F
# 33                    84  37.750000     Fail              F          F
# 34                    80  64.750000     Pass              C          C
# 35                    95  55.000000     Pass              D          D
# 36                    69  54.500000     Pass              D          D
# 37                    96  46.500000     Fail              F          F
# 38                    68  41.000000     Fail              F          F
# 39                    83  68.000000     Pass              C          C
# 40                    94  39.250000     Fail              F          F
# 41                    94  54.750000     Pass              D          D
# 42                    95  34.000000     Fail              F          F
# 43                    77  25.000000     Fail              F          F
# 44                    98  53.000000     Pass              D          D
# 45                    91  57.000000     Pass              D          D
# 46                    83  39.500000     Fail              F          F
# 47                    82  79.333333     Pass              B          B
# 48                    91  34.000000     Fail              F          F
# 49                    96  33.000000     Fail              F          F

# %%
def get_grade(Avg_score):
    if Avg_score >= 90:
        return 'A'
    if Avg_score >= 75:
        return 'B'
    if Avg_score >= 60:
        return 'C'
    if Avg_score >= 50:
        return 'D'
    else:
        return 'F'

# %%
df['Grade_Category'] = df['Avg_score'].apply(lambda x: get_grade(x))
df
# Out:
#     StudentID        Name   Math    Science    English    History Grade  \
# 0        1001   Student_1  82.00   4.000000  16.000000  16.000000     F
# 1        1002   Student_2  71.00  40.000000  23.000000  29.000000     F
# 2        1003   Student_3  82.00  72.000000  97.000000   5.000000     C
# 3        1004   Student_4  45.75  33.000000  10.000000  36.000000     F
# 4        1005   Student_5  99.00  50.319149  15.000000  45.000000     D
# 5        1006   Student_6   2.00  61.000000  58.000000  98.000000     D
# 6        1007   Student_7  45.75  98.000000  92.000000  62.000000     B
# 7        1008   Student_8  29.00  85.000000  58.000000  31.000000     D
# 8        1009   Student_9  63.00  64.000000  89.000000  66.000000     C
# 9        1010  Student_10  32.00  46.000000  18.000000  24.000000     F
# 10       1011  Student_11  21.00   0.000000  70.000000  53.000000     F
# 11       1012  Student_12  45.75  13.000000  32.000000  45.000000     F
# 12       1013  Student_13  45.75   8.000000  38.000000  42.444444     F
# 13       1014  Student_14  41.00  89.000000   0.000000  85.000000     D
# 14       1015  Student_15  45.75  50.319149  56.000000  26.000000     F
# 15       1016  Student_16  14.00  62.000000  22.000000  89.000000     F
# 16       1017  Student_17  46.00  51.000000  41.000000  32.000000     F
# 17       1018  Student_18  54.00   3.000000  15.000000  47.000000     F
# 23                    88  18.500000     Fail              F          F
# 24                    85  24.333333     Fail              F          F
# 25                    69  57.000000     Pass              D          D
# 26                    85  37.500000     Fail              F          F
# 27                    93  51.000000     Pass              D          D
# 28                    66  78.666667     Pass              B          B
# 29                    63  61.333333     Pass              C          C
# 30                    70  45.750000     Fail              F          F
# 31                    88  45.750000     Fail              F          F
# 32                    95  47.750000     Fail              F          F
# 33                    84  37.750000     Fail              F          F
# 34                    80  64.750000     Pass              C          C
# 35                    95  55.000000     Pass              D          D
# 36                    69  54.500000     Pass              D          D
# 37                    96  46.500000     Fail              F          F
# 38                    68  41.000000     Fail              F          F
# 39                    83  68.000000     Pass              C          C
# 40                    94  39.250000     Fail              F          F
# 41                    94  54.750000     Pass              D          D
# 42                    95  34.000000     Fail              F          F
# 43                    77  25.000000     Fail              F          F
# 44                    98  53.000000     Pass              D          D
# 45                    91  57.000000     Pass              D          D
# 46                    83  39.500000     Fail              F          F
# 47                    82  79.333333     Pass              B          B
# 48                    91  34.000000     Fail              F          F
# 49                    96  33.000000     Fail              F          F

# %%
bins = [0, 50, 60, 75, 90, 100]
labels = ['F', 'D', 'C', 'B', 'A']
#cut is used to convert the continuous numeric scores into categorical grades using predefined ranges
df['Grade'] = pd.cut(df['Avg_score'], bins=bins, labels=labels, right=False)
print(df[['Name', 'Avg_score', 'Grade']].head(10))
# Out:
#          Name  Avg_score Grade
# 0   Student_1  32.000000     F
# 1   Student_2  40.750000     F
# 2   Student_3  64.000000     C
# 3   Student_4  26.333333     F
# 4   Student_5  53.000000     D
# 5   Student_6  54.750000     D
# 6   Student_7  84.000000     B
# 7   Student_8  50.750000     D
# 8   Student_9  70.500000     C
# 9  Student_10  30.000000     F

# %% [markdown]
# ## Challenge 2:
# #### Calculate z-scores for each subject and identify outlier students

# %%
# Calculate z-scores
subjects=df[['Math','Science','English','History']]
for subject in subjects:
    df[f"{subject}_z"] = ((df[subject] - df[subject].mean()) / df[subject].std())

# %%
outliers = df[(df['Math_z'].abs() > 3) |(df['Science_z'].abs() > 3) | (df['English_z'].abs() > 3)]
print("Outlier Students:")
print(outliers[['StudentID', 'Name','Math_z', 'Science_z', 'English_z']])
# Out:
# Outlier Students:
# Empty DataFrame
# Columns: [StudentID, Name, Math_z, Science_z, English_z]
# Index: []

# %% [markdown]
# ## Challenge 3
# #### Generate a summary report by Grade (A, B, C, etc.) showing statistics.

# %%
grade_summary = df.groupby('Grade')['Avg_score'].agg(
    Student_Count='count',
    Average_Score='mean',
    Min_Score='min',
    Max_Score='max'
).reset_index()
print("Grade-wise Summary Report:")
print(grade_summary)
# Out:
# Grade-wise Summary Report:
#   Grade  Student_Count  Average_Score  Min_Score  Max_Score
# 0     F             31      35.322581  18.500000      47.75
# 1     D             11      54.045455  50.750000      57.00
# 2     C              5      65.716667  61.333333      70.50
# 3     B              3      80.666667  78.666667      84.00
# 4     A              0            NaN        NaN        NaN
# C:\Users\USER 10\AppData\Local\Temp\ipykernel_14988\1038353275.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grade_summary = df.groupby('Grade')['Avg_score'].agg(
