# %%
import pandas as pd 
df=pd.read_csv("sales_data_raw.csv")
df
# Out:
#      OrderID        Date   Region     Product     Category  Quantity  \
# 0       1305  2024-07-13    North       Phone  Electronics        14
# 1       1500  2024-10-06  Central       Phone  Electronics        15
# 2       1442  2024-11-13     West      Laptop  Accessories         2
# 3       1154  2024-11-22    North      Laptop  Accessories        10
# 4       1414  2024-02-22    North    Keyboard  Electronics         4
# ..       ...         ...      ...         ...          ...       ...
# 510     1072  2024-06-10    North  Headphones  Electronics         4
# 511     1107  2024-09-17     East  Headphones  Electronics         7
# 512     1271  2024-08-20     East      Tablet  Accessories        15
# 513     1436  2024-10-01  Central       Phone  Electronics         3
# 514     1103  2024-05-18    South      Laptop  Accessories        15
#
#      UnitPrice  CustomerID SalesRep PaymentMethod  TotalAmount
# 0          599        5060    Diana   Net Banking         8386
# ...

# %%
df.describe()
# Out:
#            OrderID    Quantity    UnitPrice   CustomerID    TotalAmount
# count   515.000000  515.000000   515.000000   515.000000     515.000000
# mean   1250.603883   12.106796   463.097087  5104.452427    5089.194175
# std     143.913487   20.056201   466.886482    56.813498   11867.721283
# min    1001.000000    1.000000    19.000000  5001.000000      19.000000
# 25%    1124.500000    5.000000    49.000000  5057.500000     418.000000
# 50%    1252.000000   10.000000   299.000000  5108.000000    1343.000000
# 75%    1374.500000   14.500000   899.000000  5153.500000    6589.000000
# max    1500.000000  181.000000  1299.000000  5200.000000  187056.000000

# %%
df.head(5)
# Out:
#    OrderID        Date   Region   Product     Category  Quantity  UnitPrice  \
# 0     1305  2024-07-13    North     Phone  Electronics        14        599
# 1     1500  2024-10-06  Central     Phone  Electronics        15         49
# 2     1442  2024-11-13     West    Laptop  Accessories         2       1299
# 3     1154  2024-11-22    North    Laptop  Accessories        10         19
# 4     1414  2024-02-22    North  Keyboard  Electronics         4        299
#
#    CustomerID SalesRep PaymentMethod  TotalAmount
# 0        5060    Diana   Net Banking         8386
# 1        5199      Bob   Credit Card          735
# 2        5008  Charlie          Cash         2598
# 3        5198      Eve           UPI          190
# 4        5063    Alice   Net Banking         1196

# %%
df.isnull().sum()
# Out:
# OrderID           0
# Date              0
# Region           10
# Product           0
# Category          0
# Quantity          0
# UnitPrice         0
# CustomerID        0
# SalesRep         10
# PaymentMethod     5
# TotalAmount       0
# dtype: int64

# %%
df['Region'].fillna('Unknown',inplace=True)
# Out:
# C:\Users\USER 10\AppData\Local\Temp\ipykernel_15236\784993391.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Region'].fillna('Unknown',inplace=True)

# %%
df['Region'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['SalesRep'].fillna('Unknown',inplace=True)
# Out:
# C:\Users\USER 10\AppData\Local\Temp\ipykernel_15236\2502912724.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['SalesRep'].fillna('Unknown',inplace=True)

# %%
df['SalesRep'].isnull().sum()
# Out:
# np.int64(0)

# %%
Payment=df['PaymentMethod'].mode()[0]

# %%
df['PaymentMethod'].fillna(Payment,inplace=True)
# Out:
# C:\Users\USER 10\AppData\Local\Temp\ipykernel_15236\4215254032.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PaymentMethod'].fillna(Payment,inplace=True)

# %%
df['PaymentMethod'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 510    False
# 511    False
# 512    False
# 513    False
# 514    False
# Length: 515, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(13)

# %%
df[df.duplicated()]
# Out:
#      OrderID        Date   Region     Product     Category  Quantity  \
# 101     1105  2024-06-11     East  Headphones  Accessories         4
# 182     1282  2024-03-15  Central    Keyboard  Electronics        14
# 199     1111  2024-05-14    North     Charger  Electronics        12
# 275     1123  2024-08-01    South       Mouse  Electronics        12
# 332     1066  2024-04-15    North  Headphones  Electronics        12
# 361     1425  2024-11-06     West      Tablet  Accessories         7
# 406     1280  2024-06-09    North       Mouse  Accessories         3
# 458     1319  2024-08-13    North      Tablet  Electronics        13
# 482     1314  2024-12-30  Central       Mouse  Accessories         4
# 490     1414  2024-02-22    North    Keyboard  Electronics         4
# 494     1309  2024-01-22     West  Headphones  Accessories        13
# 499     1100  2024-05-08  Central       Mouse  Accessories         2
# 507     1185  2024-06-13    North       Mouse  Electronics         5
#
# ...

# %%
Data=df.drop_duplicates().reset_index(drop=True)

# %%
Data
# Out:
#      OrderID        Date   Region     Product     Category  Quantity  \
# 0       1305  2024-07-13    North       Phone  Electronics        14
# 1       1500  2024-10-06  Central       Phone  Electronics        15
# 2       1442  2024-11-13     West      Laptop  Accessories         2
# 3       1154  2024-11-22    North      Laptop  Accessories        10
# 4       1414  2024-02-22    North    Keyboard  Electronics         4
# ..       ...         ...      ...         ...          ...       ...
# 497     1072  2024-06-10    North  Headphones  Electronics         4
# 498     1107  2024-09-17     East  Headphones  Electronics         7
# 499     1271  2024-08-20     East      Tablet  Accessories        15
# 500     1436  2024-10-01  Central       Phone  Electronics         3
# 501     1103  2024-05-18    South      Laptop  Accessories        15
#
#      UnitPrice  CustomerID SalesRep PaymentMethod  TotalAmount
# 0          599        5060    Diana   Net Banking         8386
# ...

# %%
Data.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Product'].str.strip().str.title().reset_index()
# Out:
#      index     Product
# 0        0       Phone
# 1        1       Phone
# 2        2      Laptop
# 3        3      Laptop
# 4        4    Keyboard
# ..     ...         ...
# 510    510  Headphones
# 511    511  Headphones
# 512    512      Tablet
# 513    513       Phone
# 514    514      Laptop
#
# [515 rows x 2 columns]

# %%
df['Region'].str.title().reset_index()
# Out:
#      index   Region
# 0        0    North
# 1        1  Central
# 2        2     West
# 3        3    North
# 4        4    North
# ..     ...      ...
# 510    510    North
# 511    511     East
# 512    512     East
# 513    513  Central
# 514    514    South
#
# [515 rows x 2 columns]

# %%
quantity_mean=df['Quantity'].mean()

# %%
quantity_std=df['Quantity'].std()

# %%
quantity_mean
# Out:
# np.float64(12.106796116504855)

# %%
quantity_std
# Out:
# 20.056201492665096

# %%
df['Outlier_mask']=df['Quantity']>(quantity_mean+(3*quantity_std))

# %%
df
# Out:
#      OrderID        Date   Region     Product     Category  Quantity  \
# 0       1305  2024-07-13    North       Phone  Electronics        14
# 1       1500  2024-10-06  Central       Phone  Electronics        15
# 2       1442  2024-11-13     West      Laptop  Accessories         2
# 3       1154  2024-11-22    North      Laptop  Accessories        10
# 4       1414  2024-02-22    North    Keyboard  Electronics         4
# ..       ...         ...      ...         ...          ...       ...
# 510     1072  2024-06-10    North  Headphones  Electronics         4
# 511     1107  2024-09-17     East  Headphones  Electronics         7
# 512     1271  2024-08-20     East      Tablet  Accessories        15
# 513     1436  2024-10-01  Central       Phone  Electronics         3
# 514     1103  2024-05-18    South      Laptop  Accessories        15
#
#      UnitPrice  CustomerID SalesRep PaymentMethod  TotalAmount  Outlier_mask
# ...

# %%
df.sort_values(by="Outlier_mask")
# Out:
#      OrderID       Date   Region     Product     Category  Quantity  \
# 0       1305 2024-07-13    North       Phone  Electronics        14
# 346     1222 2024-11-19  Unknown      Tablet  Accessories         8
# 345     1437 2024-04-01     West     Charger  Accessories        12
# 344     1411 2024-02-23  Central      Tablet  Electronics         7
# 343     1143 2024-02-21     East    Keyboard  Accessories         1
# ..       ...        ...      ...         ...          ...       ...
# 500     1373 2024-06-24     West      Tablet  Accessories       181
# 395     1327 2024-01-04  Central      Tablet  Accessories       175
# 216     1249 2024-05-07  Central  Headphones  Accessories       173
# 84      1040 2024-08-31     West  Headphones  Accessories       165
# 462     1320 2024-10-03     East  Headphones  Accessories       162
#
#      UnitPrice  CustomerID SalesRep PaymentMethod  TotalAmount  Outlier_mask  \
# ...

# %%
product_median=df.groupby('Product')['Quantity'].transform('median')

# %%
product_median
# Out:
# 0       9.5
# 1       9.5
# 2      10.0
# 3      10.0
# 4      10.0
#        ...
# 510    12.0
# 511    12.0
# 512     9.5
# 513     9.5
# 514    10.0
# Name: Quantity, Length: 515, dtype: float64

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Month']=df['Date'].dt.month

# %%
df
# Out:
#      OrderID       Date   Region     Product     Category  Quantity  \
# 0       1305 2024-07-13    North       Phone  Electronics        14
# 1       1500 2024-10-06  Central       Phone  Electronics        15
# 2       1442 2024-11-13     West      Laptop  Accessories         2
# 3       1154 2024-11-22    North      Laptop  Accessories        10
# 4       1414 2024-02-22    North    Keyboard  Electronics         4
# ..       ...        ...      ...         ...          ...       ...
# 510     1072 2024-06-10    North  Headphones  Electronics         4
# 511     1107 2024-09-17     East  Headphones  Electronics         7
# 512     1271 2024-08-20     East      Tablet  Accessories        15
# 513     1436 2024-10-01  Central       Phone  Electronics         3
# 514     1103 2024-05-18    South      Laptop  Accessories        15
#
#      UnitPrice  CustomerID SalesRep PaymentMethod  TotalAmount  Outlier_mask  \
# ...

# %%
df['Year']=df['Date'].dt.year

# %%
df
# Out:
#      OrderID       Date   Region     Product     Category  Quantity  \
# 0       1305 2024-07-13    North       Phone  Electronics        14
# 1       1500 2024-10-06  Central       Phone  Electronics        15
# 2       1442 2024-11-13     West      Laptop  Accessories         2
# 3       1154 2024-11-22    North      Laptop  Accessories        10
# 4       1414 2024-02-22    North    Keyboard  Electronics         4
# ..       ...        ...      ...         ...          ...       ...
# 510     1072 2024-06-10    North  Headphones  Electronics         4
# 511     1107 2024-09-17     East  Headphones  Electronics         7
# 512     1271 2024-08-20     East      Tablet  Accessories        15
# 513     1436 2024-10-01  Central       Phone  Electronics         3
# 514     1103 2024-05-18    South      Laptop  Accessories        15
#
#      UnitPrice  CustomerID SalesRep PaymentMethod  TotalAmount  Outlier_mask  \
# ...

# %%
df['HighValue']=df['TotalAmount']>df['TotalAmount'].quantile(0.95)

# %%
df.sort_values(by="HighValue")
# Out:
#      OrderID       Date   Region  Product     Category  Quantity  UnitPrice  \
# 0       1305 2024-07-13    North    Phone  Electronics        14        599
# 347     1096 2024-12-10     West   Tablet  Accessories        17        899
# 346     1222 2024-11-19  Unknown   Tablet  Accessories         8        299
# 345     1437 2024-04-01     West  Charger  Accessories        12         79
# 344     1411 2024-02-23  Central   Tablet  Electronics         7        299
# ..       ...        ...      ...      ...          ...       ...        ...
# 223     1075 2024-12-16     East    Phone  Electronics        19       1299
# 170     1235 2024-07-19     East   Laptop  Electronics        16       1299
# 286     1311 2024-06-06    South  Charger  Accessories        16       1299
# 451     1014 2024-12-25     East   Laptop  Accessories        15       1299
# 252     1372 2024-09-02     East  Charger  Electronics        19       1299
#
# ...

# %%
df.groupby(['Region','Product']).agg({'TotalAmount':['sum','mean']})
# Out:
#                        TotalAmount
#                                sum          mean
# Region  Product
# Central   Keyboard             152    152.000000
#           Laptop              3294   1647.000000
#         Charger              44778   4070.727273
#         Headphones          217647  21764.700000
#         Keyboard            117858   5124.260870
#         Laptop               47034   3135.600000
#         Mouse                28375   1576.388889
#         Phone                43545   4354.500000
#         Tablet              116059   6108.368421
# East      Headphones          7192   7192.000000
#           Laptop               209    209.000000
#         Charger              51966   4724.181818
#         Headphones           56571   4714.250000
#         Keyboard             55763   3485.187500
#         Laptop               68049   5670.750000
#         Mouse                19269   1926.900000
#         Phone                96420   5671.764706
# ...

# %%
sales=df.groupby(['Month','Product']).agg({'Quantity':'sum'})

# %%
best_selling_product = sales.loc[sales.groupby(['Month'])['Quantity'].idxmax()]

# %%
best_selling_product
# Out:
#                   Quantity
# Month Product
# 1     Tablet           197
# 2     Keyboard          85
# 3     Keyboard          63
# 4     Mouse            131
# 5     Headphones       247
# 6     Tablet           264
# 7     Keyboard          87
# 8     Tablet           284
# 9     Phone            157
# 10    Headphones       197
# 11    Keyboard         195
# 12    Tablet           103

# %%
pivot_table_example = pd.pivot_table(df, 
                                     values='TotalAmount', 
                                     index='Region', 
                                     columns='Product', 
                                     aggfunc='sum', 
                                    fill_value=0)

# %%
pivot_table_example
# Out:
# Product    Headphones      Keyboard      Laptop      Phone    Charger  \
# Region
# Central               0           152        3294          0    44778
# East               7192             0         209          0    51966
# North              4792             0           0          0   121229
# South                 0             0        2093          0    67862
# Unknown               0             0           0          0     5196
# West              14289             0          98       5391    43321
# central               0             0           0          0        0
# east                  0             0           0          0        0
# north                 0             0           0          0        0
# south                 0             0           0          0     1798
# west                  0             0           0          0        0
#
# Product  Headphones  Keyboard  Laptop   Mouse   Phone  Tablet
# Region
# ...

# %%
a=df.groupby('SalesRep')['TotalAmount'].sum().idxmax()

# %%
a
# Out:
# 'Charlie'

# %%
a=df.groupby('SalesRep')['TotalAmount'].sum()

# %%
a
# Out:
# SalesRep
# Alice      368308
# Bob        317880
# Charlie    516371
# Diana      472319
# Eve        406726
# Frank      472463
# Unknown     66868
# Name: TotalAmount, dtype: int64

# %%
salesrep_revenue = df.groupby('SalesRep')['TotalAmount'].sum() 
top_salesrep = salesrep_revenue.idxmax() 
print(top_salesrep, salesrep_revenue[top_salesrep])
# Out:
# Charlie 516371

# %%
top3_orders = df.groupby('SalesRep')['OrderID'].count().nlargest(3)

# %%
top3_orders.reset_index()
# Out:
#   SalesRep  OrderID
# 0  Charlie       94
# 1      Eve       93
# 2    Alice       83
